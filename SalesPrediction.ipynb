# %% [markdown]
# # Advertising Sales Channel Prediction

# %% [markdown]
# # Problem Statement

# %% [markdown]
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales generated from all the sales channel.

# %% [markdown]
# # Importing requried Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
## Loading dataset
df=pd.read_csv('Advertisingsales.csv')
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
## Checking the shape the dataset
df.shape
# Out:
# (200, 5)

# %% [markdown]
# 1- Our dataset have 200 rows and 5 columns including Target column
#
# 2- Sales is our target attribute.
#
# 3- This is a regression problem statement

# %%
## Checking datatype of dataset
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
## Checking info for our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# We can clearly see there is no null values present in our dataset.

# %%
## Plotting Null values on heatmap
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='Accent')
# Out:
# <AxesSubplot:>

# %% [markdown]
# No null value present in our dataset

# %% [markdown]
# # Statistical Summary

# %%
## statistical Summary
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# 1- Our dataset seems to be normally distributed because mean and median values are nearly close to each other.
#
# 2-There could be some outliers present in newspaper column because there is a compartively high difference between 3rd quantile and max values.
#
# 3- Radio attribute has a minimum zero value in our dataset which could be part of further investigation in our dataset.

# %%
## Correlation Plot
plt.figure(figsize=(10,6))
plt.title('Correlation Heatmap',fontsize=15)
sns.heatmap(df.corr(),annot=True,linewidths=.2)
# Out:
# <AxesSubplot:title={'center':'Correlation Heatmap'}>

# %%
## Correlation with target attribute
df.corr()['sales'].sort_values(ascending=False)
# Out:
# sales         1.000000
# TV            0.782224
# radio         0.576223
# newspaper     0.228299
# Unnamed: 0   -0.051616
# Name: sales, dtype: float64

# %% [markdown]
# Unnamed:0 have least and negative correlation with our target attribute.
#
# TV and radio has a strong and positive correlation with targer attribute.
#
# Newspaper and radio are correlated to each other.

# %%
df.corr()['sales'].sort_values(ascending=False).drop(['sales']).plot.bar(figsize=(10,6),grid=True,title='Coreelation with Target',fontsize=10)
# Out:
# <AxesSubplot:title={'center':'Coreelation with Target'}>

# %% [markdown]
# TV, Radio have correlation more than 50% with target variable.
#
# Unnnamed:0 has negative and very weak correlation with our target variable, we can drop as it has no significance with target variable.

# %% [markdown]
# # Data Analysis and Visualization

# %%
plt.figure(figsize=(12,6))
sns.set_style('ticks')
plt.title('TV Advertising Vs Sales ',fontsize=10)
sns.scatterplot(df['TV'],df['sales'],data=df)
# Out:
# <AxesSubplot:title={'center':'TV Advertising Vs Sales '}, xlabel='TV', ylabel='sales'>

# %% [markdown]
# There is a linear positive correlation between TV advertising and Sales.
#
# As Tv advertising inceases sales also increases.

# %%
plt.figure(figsize=(12,6))
sns.set_style('ticks')
plt.title('Newspaper Advertising Vs Sales ',fontsize=15)
sns.scatterplot(df['newspaper'],df['sales'],data=df)
plt.show()

# %% [markdown]
# from above scatter plot we can see that there is a moderate realtionship with sales.
#
# Datapoints are scattered we can't conclude from this plot
#
# Some points are widly scattered.

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('radio Advertising Vs Sales ',fontsize=15)
sns.scatterplot(df['radio'],df['sales'],data=df)
plt.show()

# %% [markdown]
# This plot shows a positive linear relation between radio advertising and sales.
#
# As radio advertising increases, sales also get increases.

# %%
## Let's plot the pairplot for all the attributes together
sns.pairplot(df)

# %% [markdown]
# # Data Distribution

# %%
plt.figure(figsize=(14,10))
plot=1
for col in df:
    if plot<=5:
        plt.subplot(3,3,plot)
        sns.distplot(df[col])
        plt.xlabel(col)
        plot=plot+1

# %% [markdown]
# It shows that our dataset is approimately bell shaped in distribution means normally distributed.
#
# Newspaper attribute is a little right skewed.
#
# our target attribute is Normally distributed.

# %% [markdown]
# # Checking Outliers

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see that there are some outliers in newspaper column

# %%
def outlier_normally(df,col):
    lower_boundary=df[col].mean()-3*df[col].std()
    upper_boundary=df[col].mean()+3*df[col].std()
    print(lower_boundary,upper_boundary)
    df[col]=np.where((df[col]<lower_boundary)|(df[col]>upper_boundary),df[col].median(),df[col])
    sns.boxplot(df[col])

# %%
outlier_normally(df,'newspaper')
# Out:
# -34.7818625155685 95.8898625155685

# %% [markdown]
# We have replaced the outliers with median , now there is no outliers present in our dataset.
#
# We can see that our dataset has no outliers present.

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.658874
# sales         0.407571
# dtype: float64

# %% [markdown]
# We can see that for Newspaper attribute skewness is more than 0.5 so we will remove this with some transformation methods.

# %%
df['newspaper']=np.sqrt(df['newspaper'])

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper    -0.040656
# sales         0.407571
# dtype: float64

# %% [markdown]
# Now we can see that skewness is completly removed from our dataset.

# %% [markdown]
# # Splitting data into Input and Output Variable

# %%
x=df.drop(['Unnamed: 0','sales'],axis=1)  ## We have drop unnamed :0 because this attribute has no significance for predicting sales.
y=df[['sales']]

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8   8.318654
# 1     44.5   39.3   6.715653
# 2     17.2   45.9   8.324662
# 3    151.5   41.3   7.648529
# 4    180.8   10.8   7.641989
# ..     ...    ...        ...
# 195   38.2    3.7   3.714835
# 196   94.2    4.9   2.846050
# 197  177.0    9.3   2.529822
# 198  283.6   42.0   8.136338
# 199  232.1    8.6   2.949576
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x_scaled=ss.fit_transform(x)
x=pd.DataFrame(x_scaled,columns=x.columns)
x
# Out:
#            TV     radio  newspaper
# 0    0.969852  0.981522   1.645000
# 1   -1.197376  1.082808   0.829028
# 2   -1.516155  1.528463   1.648059
# 3    0.052050  1.217855   1.303888
# 4    0.394182 -0.841614   1.300559
# ..        ...       ...        ...
# 195 -1.270941 -1.321031  -0.698474
# 196 -0.617035 -1.240003  -1.140710
# 197  0.349810 -0.942899  -1.301679
# 198  1.594565  1.265121   1.552196
# 199  0.993206 -0.990165  -1.088013
#
# [200 rows x 3 columns]

# %% [markdown]
# Dataset is not scaled in form of Standard Scaling

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
extra=ExtraTreesRegressor()
extra.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(extra.feature_importances_)
# Out:
# [0.62113749 0.37211876 0.00674375]

# %%
plt.figure(figsize=(15,6))
plt.title('Important Features',fontsize=15)
feat_importance=pd.Series(extra.feature_importances_,index=x.columns)
feat_importance.nlargest().plot(kind='barh')
# Out:
# <AxesSubplot:title={'center':'Important Features'}>

# %% [markdown]
# we can see that radio and TV are highly important features for our target column to predict the right sales price.

# %% [markdown]
# # Model Building

# %% [markdown]
# Importing machine learning Library

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1)
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean())
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std())
    print('Training accuracy',clf.score(x_train,y_train))
    print('Test Accuracy',clf.score(x_test,y_test))
    print('MAE',mean_absolute_error(y_test,pred))
    print('MSE',mean_squared_error(y_test,pred))
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    
    return final_r

# %% [markdown]
# # Linerar regression

# %%
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 92 is 0.9515375445674434
# cross validation score 0.8874289458669635
# Standard Deviation 0.039909298543301
# Training accuracy 0.8908107058793879
# Test Accuracy 0.9188727395820788
# MAE 1.159204355867456
# MSE 2.079624306279034
# RMSE 1.4420902559406723
# 92

# %% [markdown]
# # Lasso Regression

# %%
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 83 is 0.8616707145490253
# cross validation score 0.8175135660884789
# Standard Deviation 0.048169557907936526
# Training accuracy 0.8207247509119464
# Test Accuracy 0.8407357569037717
# MAE 1.4975447804611437
# MSE 4.082595533953025
# RMSE 2.0205433759147624
# 83

# %% [markdown]
# # Ridge regression

# %%
ridge=Ridge()
maxr2_score(ridge,x,y)
# Out:
# max r2 score corresponding to 92 is 0.95125522506385
# cross validation score 0.8874948915182891
# Standard Deviation 0.04033574508512031
# Training accuracy 0.8907790915823749
# Test Accuracy 0.9186462100001408
# MAE 1.163250094499078
# MSE 2.085431188235391
# RMSE 1.4441022083756367
# 92

# %% [markdown]
# # Decision Tree Regressor

# %%
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 75 is 0.9775869554837227
# cross validation score 0.9478426153594107
# Standard Deviation 0.008549992047199396
# Training accuracy 1.0
# Test Accuracy 0.9354278090512248
# MAE 0.8724999999999998
# MSE 1.6552499999999994
# RMSE 1.2865651946170469
# 75

# %% [markdown]
# # KNN

# %%
knn=KNeighborsRegressor()
maxr2_score(knn,x,y)
# Out:
# max r2 score corresponding to 61 is 0.9639487545207585
# cross validation score 0.9330030376371383
# Standard Deviation 0.03059765905442555
# Training accuracy 0.9513356956500039
# Test Accuracy 0.9234273877374279
# MAE 0.8995000000000003
# MSE 1.9628699999999994
# RMSE 1.4010246250512512
# 61

# %% [markdown]
# # Support Vector

# %%
svm=SVR()
maxr2_score(svm,x,y)
# Out:
# max r2 score corresponding to 45 is 0.9763358231098598
# cross validation score 0.9045732839730547
# Standard Deviation 0.055209774393147254
# Training accuracy 0.9272924392642631
# Test Accuracy 0.9146031876225645
# MAE 0.8671469648057638
# MSE 2.189070428164418
# RMSE 1.4795507521421556
# 45

# %% [markdown]
# # Random Forest

# %%
rf=RandomForestRegressor()
maxr2_score(rf,x,y)
# Out:
# max r2 score corresponding to 47 is 0.9890581191013064
# cross validation score 0.9752114043843692
# Standard Deviation 0.008570210151776394
# Training accuracy 0.9960896187152561
# Test Accuracy 0.9839247779325195
# MAE 0.4968500000000028
# MSE 0.41207385000000246
# RMSE 0.6419297858800466
# 47

# %% [markdown]
# # Adaboost Regessor

# %%
adb=AdaBoostRegressor()
maxr2_score(adb,x,y)
# Out:
# max r2 score corresponding to 70 is 0.9735622052346932
# cross validation score 0.9504434249707682
# Standard Deviation 0.016847559030267464
# Training accuracy 0.9757401658171141
# Test Accuracy 0.9535566470050513
# MAE 0.894553528474583
# MSE 1.1905335550078144
# RMSE 1.0911157385941304
# 70

# %% [markdown]
# # Gardient Boost Regressor

# %%
gb=GradientBoostingRegressor()
maxr2_score(gb,x,y)
# Out:
# max r2 score corresponding to 48 is 0.9906887377369269
# cross validation score 0.9775677704536168
# Standard Deviation 0.009375050499968772
# Training accuracy 0.9985290210924179
# Test Accuracy 0.9826889019592171
# MAE 0.4800667062341358
# MSE 0.4437544182872326
# RMSE 0.666148946022759
# 48

# %%
Best_model=best_model=pd.DataFrame({'Model':['LinearRegression','Lasso','Ridge','DecisionTreeRegressor','KNeighborsRegressor','SVM','RandomForestRegressor','AdaBoostRegressor','GradientBoostingRegressor'],
                         'R_2 score':[95.15,86.16,95.12,97.97,96.39,97.63,98.90,97.73,99.05],
                         'Cross_validation':[88.74,81.75,88.74,94.72,93.30,90.43,97.59,92.22,97.75]})
best_model
# Out:
#                        Model  R_2 score  Cross_validation
# 0           LinearRegression      95.15             88.74
# 1                      Lasso      86.16             81.75
# 2                      Ridge      95.12             88.74
# 3      DecisionTreeRegressor      97.97             94.72
# 4        KNeighborsRegressor      96.39             93.30
# 5                        SVM      97.63             90.43
# 6      RandomForestRegressor      98.90             97.59
# 7          AdaBoostRegressor      97.73             92.22
# 8  GradientBoostingRegressor      99.05             97.75

# %% [markdown]
# From above table it is clear that Random Forest Regressor if our best model because the difference between R_2 score and Cross validation score is minimum which shows that our Model is not overfit and best among all.

# %% [markdown]
# # Hyperparameter Tuning for Random Forest

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=48,test_size=.20)
forest=RandomForestRegressor()
param={'n_estimators':[50,100,200],'max_depth':[10,50,None],'max_features': [1,2,3],'bootstrap': [True, False]}
glf=GridSearchCV(estimator=forest,param_grid=param,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'bootstrap': True, 'max_depth': 10, 'max_features': 3, 'n_estimators': 100}

# %%
forest=RandomForestRegressor(bootstrap=True,max_depth=10,max_features=3,n_estimators=50)
forest.fit(x_train,y_train)
pred=forest.predict(x_test)
print('Error')
print(' Mean Absolute Error (MAE) :',mean_absolute_error(pred,y_test))
print('Mean Squared Error (MSE) :',mean_squared_error(pred,y_test))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(pred,y_test)))
print('R_2 score:',r2_score(pred,y_test))
## best fit line
sns.regplot(pred,y_test,color='r')
# Out:
# Error
#  Mean Absolute Error (MAE) : 0.5263740476190458
# Mean Squared Error (MSE) : 0.47611619712358016
# Root Mean Squared Error : 0.6900117369462495
# R_2 score: 0.9833069002956201
# <AxesSubplot:ylabel='sales'>

# %% [markdown]
# We can see that with Hyperparameter tuning our R_2 score is 98.57 which is improved hence we will save this as our best Model.

# %% [markdown]
# # Saving our Model

# %%
import joblib
joblib.dump(forest,'advertiseforest.pkl')
# Out:
# ['advertiseforest.pkl']

# %% [markdown]
# # Loading Model

# %%
loaded_model=joblib.load('advertiseforest.pkl')
prediction=loaded_model.predict(x_test)
